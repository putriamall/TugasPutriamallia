# %%
#MEMBUAT PROGRAM KONVERSI TEMPERATUR
print("\nPROGRAM PUTRI AMALLIA KONVERSI TEMPERATUR\n")

#CELCIUS
celcius = float(input('Masukan suhu dalam celcius :'))
print("suhu adalah",celcius,"Celcius")

#REAMUR
reamur = (4/5)*celcius
print("suhu dalam reamur adalah",reamur,"Reamur")

#FARENHEIT
farenheit = ((9/5)*celcius) +32
print("suhu dalam farenheit adalah",farenheit,"Farenheit")

#KELVIN
kelvin = celcius + 273
print("suhu dalam kelvin adalah",kelvin,"Kelvin")
# Out:
# PROGRAM PUTRI AMALLIA KONVERSI TEMPERATUR
#
# Masukan suhu dalam celcius :36
# suhu adalah 36.0 Celcius
# suhu dalam reamur adalah 28.8 Reamur
# suhu dalam farenheit adalah 96.8 Farenheit
# suhu dalam kelvin adalah 309.0 Kelvin

# %%
nama     =  (input('Masukan Nama : '))
nim      = (input('Masukan NIM : '))
fakultas = (input('Masukan Fakultas : '))
jurusan  = (input('Masukan Jurusan : '))
asal     = (input('Masukan Asal Kota : '))
alamat   = (input('Masukan Alamat : '))
print ("Nama Saya"
       ,nama,"NIM Saya"
       ,nim,"Fakultas Saya Adalah"
       ,fakultas,"Jurusan Saya adalah"
       ,jurusan,"Saya berasal dari kota",asal,
       "Saya tinggal di",alamat)
# Out:
# Masukan Nama : putri amallia ramadhani
# Masukan NIM : 19SA1084
# Masukan Fakultas : Ilmu komputer
# Masukan Jurusan : Informatika
# Masukan Asal Kota : Purbalingga
# Masukan Alamat : Karangreja 01/04, purbalingga, jawa tengah
# Nama Saya putri amallia ramadhani NIM Saya 19SA1084 Fakultas Saya Adalah Ilmu komputer Jurusan Saya adalah Informatika Saya berasal dari kota Purbalingga Saya tinggal di Karangreja 01/04, purbalingga, jawa tengah

# %%
# Menyelesaikan Persamaan Kuadrat ax**2 + bx + c = 0
 
# Mengimpor Modul Cmath
import cmath
 
# Menginput Angka
a = int(input('Tulis a: '))
b = int(input('Tulis b: '))
c = int(input('Tulis c: '))
 
# Menghitung Diskriminan
d = (b**2) - (4*a*c)
 
# Menghitung x1 dan x2
x1 = (-b-cmath.sqrt(d))/(2*a)
x2 = (-b+cmath.sqrt(d))/(2*a)
 
#Menampilkan Hasil x1 dan x2
print('Hasil Persamaan Kuadrat adalah {0} dan {1}'.format(x1,x2))
# Out:
# Tulis a: 2
# Tulis b: 3
# Tulis c: 4
# Hasil Persamaan Kuadrat adalah (-0.75-1.1989578808281798j) dan (-0.75+1.1989578808281798j)

# %%
pilihan="y"
while pilihan=="y":
    print("""
    ##  DAFTAR MENU KOPI PUTRI  ##
    ==============================
    1. Espresso        : Rp 10.000
    2. Cappucino       : Rp 15.000
    3. Moccacino Latte : Rp 20.000
    4. Hazelnut Latte  : Rp 25.000
    ==============================
    """)
    pesan=str(input("Masukkan Nomor List Kopi = "))
    jumlahpesan=int(input("Masukkan Jumlah Pesanan = "))
    if pesan == "1":
        listnama= "Espresso"
        harga=(10000*jumlahpesan)
        ppn= int(harga * 0.1)
        if jumlahpesan >= 5:
            diskon = int(harga*0.2)
            totalharga=int(harga-diskon+ppn)
        else:
            diskon =(0)
            totalharga=int(harga+ppn)
    elif pesan == "2":
        listnama= "Cappucino"
        harga = (15000*jumlahpesan)
        ppn = int(harga * 0.1)
        if jumlahpesan >= 5:
            diskon = int(harga * 0.2)
            totalharga =int(harga-diskon+ppn)
        else:
            diskon =(0)
            totalharga =int(harga+ppn)
    elif pesan == "3":
        listnama= "Moccacino Latte"
        harga=int(20000*jumlahpesan)
        ppn = int(harga * 0.1)
        diskon=0
        totalharga=int(harga+ppn)
    elif pesan == "4":
        listnama= "Hazelnut Latte"
        harga=int(25000*jumlahpesan)
        ppn = int(harga * 0.1)
        diskon=0
        totalharga = int(harga+ppn)
    else:
        listnama = "-"
        harga = "-"
        ppn = "-"
        diskon = "-"
        totalharga = "-"
        pilihan=input("Menu tidak tersedia, Silahkan masukkan nomor list menu yang tersedia silahkan ulangi kembali y/n = ")
 
    print("==============================")
    print("##        KOPI PUTRI        ##")
    print("==============================")
    print("Menu :",listnama)
    print("Jumlah Pesan :", jumlahpesan)
    print("Harga :", harga)
    print("Diskon :", diskon)
    print("PPN :", ppn)
    print("--------------------------")
    print("Jumlah Bayar :", totalharga)
    print("--------------------------")
    pilihan=input("Apakah anda ingin order kembali y/n = ")
# Out:
#     ##  DAFTAR MENU KOPI PUTRI  ##
# ...
#     1. Espresso        : Rp 10.000
#     2. Cappucino       : Rp 15.000
#     3. Moccacino Latte : Rp 20.000
#     4. Hazelnut Latte  : Rp 25.000
# ...
#
# Masukkan Nomor List Kopi = 4
# Masukkan Jumlah Pesanan = 2
# ...
# ##        KOPI PUTRI        ##
# ...
# Menu : Hazelnut Latte
# Jumlah Pesan : 2
# Harga : 50000
# Diskon : 0
# PPN : 5000
# --------------------------
# Jumlah Bayar : 55000
# --------------------------
# Apakah anda ingin order kembali y/n = y
#
#     ##  DAFTAR MENU KOPI PUTRI  ##
# ...
#     1. Espresso        : Rp 10.000
#     2. Cappucino       : Rp 15.000
#     3. Moccacino Latte : Rp 20.000
#     4. Hazelnut Latte  : Rp 25.000
# ...
#
# Masukkan Nomor List Kopi = 2
# Masukkan Jumlah Pesanan = 1
# ...
# ##        KOPI PUTRI        ##
# ...
# Menu : Cappucino
# Jumlah Pesan : 1
# Harga : 15000
# Diskon : 0
# PPN : 1500
# --------------------------
# Jumlah Bayar : 16500
# --------------------------
# Apakah anda ingin order kembali y/n = n

# %%
pilihan="y"
while pilihan=="y":
    print("""
    ##  DAFTAR MENU KOPI PUTRI  ##
    ==============================
    1. Espresso        : Rp 10.000
    2. Cappucino       : Rp 15.000
    3. Moccacino Latte : Rp 20.000
    4. Hazelnut Latte  : Rp 25.000
    ==============================
    """)
    pesan      =str(input("    Masukkan Nomor List Kopi = "))
    jumlahpesan=int(input("    Masukkan Jumlah Pesanan  = "))
      if pesan == "1":
        listnama= "Espresso"
        
    elif pesan == "2":
        listnama= "Cappucino"
        
    elif pesan == "3":
        listnama= "Moccacino Latte"
        
    elif pesan == "4":
        listnama= "Hazelnut Latte"
       
    else:
       
        pilihan=input("Menu tidak tersedia, Silahkan masukkan nomor list menu yang tersedia silahkan ulangi kembali y/n = ")
    print("anda memilih",listnama)
    pilihan=input("    Apakah anda ingin order kembali y/n = ")
# Out:
#   File "<ipython-input-7-77cdcf8bc025>", line 14
#     if pesan == "1":
#     ^
# IndentationError: unexpected indent

# %%
pilihan="y"
while pilihan=="y":
    print("""
    ##  DAFTAR MENU KOPI PUTRI  ##
    ==============================
    1. Espresso        : Rp 10.000
    2. Cappucino       : Rp 15.000
    3. Moccacino Latte : Rp 20.000
    4. Hazelnut Latte  : Rp 25.000
    ==============================
    """)
    pesan      =str(input("    Masukkan Nomor List Kopi = "))
    jumlahpesan=int(input("    Masukkan Jumlah Pesanan  = "))
    if pesan == "1":
        listnama= "Espresso"
        harga=int(10000*jumlahpesan)
        totalharga=int(harga)
    elif pesan == "2":
        listnama= "Cappucino"
        harga = int (15000*jumlahpesan)
        totalharga =int(harga)
    elif pesan == "3":
        listnama= "Moccacino Latte"
        harga=int(20000*jumlahpesan)
        totalharga=int(harga)
    elif pesan == "4":
        listnama= "Hazelnut Latte"
        harga=int(25000*jumlahpesan)
        totalharga = int(harga)
    else:
        listnama = "-"
        harga = "-"
        totalharga = "-"
        pilihan=input("Menu tidak tersedia, Silahkan masukkan nomor list menu yang tersedia silahkan ulangi kembali y/n = ")
 
    print("    ==============================")
    print("    ##        KOPI PUTRI        ##")
    print("    ==============================")
    print("    Menu         :",listnama)
    print("    Jumlah Pesan :", jumlahpesan)
    print("    Harga        :", harga)
    print("    --------------------------")
    print("    Jumlah Bayar :", totalharga)
    print("    --------------------------")
    pilihan=input("    Apakah anda ingin order kembali y/n = ")
# Out:
#     ##  DAFTAR MENU KOPI PUTRI  ##
# ...
#     1. Espresso        : Rp 10.000
#     2. Cappucino       : Rp 15.000
#     3. Moccacino Latte : Rp 20.000
#     4. Hazelnut Latte  : Rp 25.000
# ...
#
#     Masukkan Nomor List Kopi = 3
#     Masukkan Jumlah Pesanan  = 1
# ...
#     ##        KOPI PUTRI        ##
# ...
#     Menu         : Moccacino Latte
#     Jumlah Pesan : 1
#     Harga        : 20000
#     --------------------------
#     Jumlah Bayar : 20000
#     --------------------------
#     Apakah anda ingin order kembali y/n = n
